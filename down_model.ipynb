# %%
from huggingface_hub import login, snapshot_download

# login via browser or typed token (not stored in code)
login()

repo_id = "meta-llama/Llama-2-7b-hf"

snapshot_download(
    repo_id=repo_id,
    local_dir="./llama-2-7b-hf",
    local_dir_use_symlinks=False
)
